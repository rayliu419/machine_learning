# %%
import nltk
nltk.download('popular')
from nltk.corpus import movie_reviews
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/luru/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/luru/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/luru/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/luru/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/luru/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/luru/nltk_data...
# ...

# %%
rawData = open("movie_reviews").read()
# Print the raw data
rawData[0:250]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-be6d28609335> in <module>
# ----> 1 rawData = open("movie_reviews").read()
#       2 # Print the raw data
#       3 rawData[0:250]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'movie_reviews'

# %%
# Out:
# (['plot',
#   ':',
#   'two',
#   'teen',
#   'couples',
#   'go',
#   'to',
#   'a',
#   'church',
#   'party',
#   ',',
#   'drink',
#   'and',
#   'then',
#   'drive',
#   '.',
#   'they',
#   'get',
#   'into',
#   'an',
#   'accident',
#   '.',
#   'one',
#   'of',
#   'the',
#   'guys',
#   'dies',
#   ',',
#   'but',
#   'his',
#   'girlfriend',
#   'continues',
#   'to',
#   'see',
#   'him',
#   'in',
#   'her',
#   'life',
#   ',',
#   'and',
#   'has',
#   'nightmares',
#   '.',
#   'what',
#   "'",
#   's',
#   'the',
#   'deal',
#   '?',
#   'watch',
#   'the',
#   'movie',
#   'and',
#   '"',
#   'sorta',
#   '"',
#   'find',
#   'out',
#   '.',
#   '.',
#   '.',
#   'critique',
#   ':',
#   'a',
#   'mind',
#   '-',
#   'fuck',
#   'movie',
#   'for',
#   'the',
#   'teen',
#   'generation',
#   'that',
#   'touches',
#   'on',
#   'a',
#   'very',
#   'cool',
#   'idea',
#   ',',
#   'but',
#   'presents',
#   'it',
#   'in',
#   'a',
#   'very',
#   'bad',
# ...
